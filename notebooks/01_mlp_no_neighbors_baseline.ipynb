# %%
import geopandas as gpd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import GroupKFold
from sklearn.metrics import precision_score, recall_score, f1_score, cohen_kappa_score

# =============================================================================
# 1. Load and preprocess the GeoDataFrame
# =============================================================================

# Load mesh and compute binary labels for favela classification
mesh = gpd.read_file("/home/stagiaire/Téléchargements/PR/D/mesh_rj.shp")
mesh['label'] = np.where(
    (mesh['vegetation'] <= 0.95) &
    (mesh['ghsl'] >= 0.5) &
    (mesh['osm'] <= 0.1) &
    (mesh['favelas'] > 0.9),
    1,
    np.where(
        (mesh['vegetation'] <= 0.95) &
        (mesh['ghsl'] >= 0.5) &
        (mesh['osm'] <= 0.1) &
        (mesh['favelas'] == 0),
        0,
        np.nan
    )
)
dataset = mesh[mesh['label'].notna()].copy()

# Assign each cell to a spatial zone (for grouped cross-validation)
zones = gpd.read_file("/home/stagiaire/Téléchargements/PR/D/zones.shp")
dataset['centroid'] = dataset.geometry.centroid
points_zones = gpd.sjoin(
    dataset.set_geometry('centroid'),
    zones[['fid', 'geometry']],
    how='left',
    predicate='within'
)
dataset['zone'] = points_zones['fid']
dataset = dataset.drop(columns=['centroid'])
dataset = dataset[dataset['zone'].notna()].reset_index(drop=True)

# =============================================================================
# 2. Build feature matrix and label vector
# =============================================================================

# Only 9 local features are used; neighbor features are padded with zeros
feature_columns = [
    'vegetation', 'slope', 'profile_co', 'entropy',
    'nodes', 'roads', 'mean_conne', 'min_connex', 'max_connex'
]
num_cell_features = len(feature_columns)
num_neighbors = 8
total_features = num_cell_features * (1 + num_neighbors)  # 9 * 9 = 81

X_list, y_list, groups_list = [], [], []
zero_padding = np.zeros(num_cell_features * num_neighbors, dtype=np.float32)

for _, row in dataset.iterrows():
    cell_features = row[feature_columns].values.astype(np.float32)
    padded_features = np.concatenate([cell_features, zero_padding])
    X_list.append(padded_features)
    y_list.append(int(row['label']))
    groups_list.append(int(row['zone']))

X = torch.tensor(np.vstack(X_list), dtype=torch.float32)
y = torch.tensor(np.array(y_list, dtype=np.int64))
groups = np.array(groups_list)

print("Feature matrix shape:", X.shape)
print("Number of examples:", X.shape[0])

# =============================================================================
# 3. Class balancing by undersampling
# =============================================================================

def undersample_indices(indices, labels_tensor):
    """Random undersampling of majority class within the given indices."""
    indices = np.array(indices)
    labels = labels_tensor[indices].numpy()
    class_0 = indices[labels == 0]
    class_1 = indices[labels == 1]

    if len(class_0) == 0 or len(class_1) == 0:
        return indices

    min_count = min(len(class_0), len(class_1))
    sampled_0 = np.random.choice(class_0, min_count, replace=False)
    sampled_1 = np.random.choice(class_1, min_count, replace=False)
    balanced_indices = np.concatenate([sampled_0, sampled_1])
    np.random.shuffle(balanced_indices)
    return balanced_indices

# =============================================================================
# 4. Define the MLP model
# =============================================================================

class MLP(nn.Module):
    """Simple MLP with one hidden layer for binary classification."""
    def __init__(self, input_size, hidden_size, output_size):
        super().__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        x = self.relu(self.fc1(x))
        return self.fc2(x)

# =============================================================================
# 5. Training and evaluation loop
# =============================================================================

def train_and_evaluate_mlp_no_neighbors(train_idx, test_idx):
    """Train and evaluate the MLP model on one fold with no neighbor info."""
    train_idx_bal = undersample_indices(train_idx, y)
    test_idx_bal = undersample_indices(test_idx, y)

    X_train, y_train = X[train_idx_bal], y[train_idx_bal]
    X_test, y_test = X[test_idx_bal], y[test_idx_bal]

    train_loader = DataLoader(TensorDataset(X_train, y_train), batch_size=32, shuffle=True)
    test_loader = DataLoader(TensorDataset(X_test, y_test), batch_size=32)

    model = MLP(input_size=X.shape[1], hidden_size=64, output_size=2).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)

    # Training
    model.train()
    for epoch in range(1, 401):
        for batch_x, batch_y in train_loader:
            batch_x, batch_y = batch_x.to(device), batch_y.to(device)
            optimizer.zero_grad()
            outputs = model(batch_x)
            loss = criterion(outputs, batch_y)
            loss.backward()
            optimizer.step()

        if epoch % 100 == 0:
            print(f"Epoch {epoch:03d} complete.")

    # Evaluation
    model.eval()
    all_preds, all_targets = [], []
    with torch.no_grad():
        for batch_x, batch_y in test_loader:
            outputs = model(batch_x.to(device))
            preds = torch.argmax(outputs, dim=1)
            all_preds.append(preds.cpu())
            all_targets.append(batch_y)

    all_preds = torch.cat(all_preds).numpy()
    all_targets = torch.cat(all_targets).numpy()

    precision = precision_score(all_targets, all_preds, zero_division=0)
    recall = recall_score(all_targets, all_preds, zero_division=0)
    f1 = f1_score(all_targets, all_preds, zero_division=0)
    kappa = cohen_kappa_score(all_targets, all_preds)

    print(f"Precision: {precision:.4f} | Recall: {recall:.4f} | F1: {f1:.4f} | Kappa: {kappa:.4f}")
    return precision, recall, f1, kappa

# =============================================================================
# 6. Spatial cross-validation using GroupKFold
# =============================================================================

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

num_iterations = 10
num_folds = 5
num_metrics = 4  # [Precision, Recall, F1, Kappa]
metrics_all = np.zeros((num_iterations, num_folds, num_metrics))

for iteration in range(num_iterations):
    print(f"\n=== Iteration {iteration + 1}/{num_iterations} ===")
    gkf = GroupKFold(n_splits=num_folds)
    for fold_idx, (train_idx, test_idx) in enumerate(gkf.split(X.numpy(), y.numpy(), groups)):
        print(f"\n--- Fold {fold_idx + 1}/{num_folds} ---")
        metrics = train_and_evaluate_mlp_no_neighbors(train_idx, test_idx)
        metrics_all[iteration, fold_idx] = metrics

# =============================================================================
# 7. Aggregate results and print
# =============================================================================

mean_per_fold = metrics_all.mean(axis=0)
std_per_fold = metrics_all.std(axis=0)

print(f"\n--- Per-zone results over {num_iterations} iterations ---")
for fold in range(num_folds):
    print(f"\nZone {fold + 1}")
    print(f"Precision: {mean_per_fold[fold, 0]:.2f} ± {std_per_fold[fold, 0]:.2f}")
    print(f"Recall:    {mean_per_fold[fold, 1]:.2f} ± {std_per_fold[fold, 1]:.2f}")
    print(f"F1:        {mean_per_fold[fold, 2]:.2f} ± {std_per_fold[fold, 2]:.2f}")
    print(f"Kappa:     {mean_per_fold[fold, 3]:.2f} ± {std_per_fold[fold, 3]:.2f}")

global_mean = mean_per_fold.mean(axis=0)
global_std = mean_per_fold.std(axis=0)

print("\n--- Global averages across all zones ---")
print(f"Precision: {global_mean[0]:.2f} ± {global_std[0]:.2f}")
print(f"Recall:    {global_mean[1]:.2f} ± {global_std[1]:.2f}")
print(f"F1:        {global_mean[2]:.2f} ± {global_std[2]:.2f}")
print(f"Kappa:     {global_mean[3]:.2f} ± {global_std[3]:.2f}")
# Out:
# Dimensions of X: torch.Size([16969, 81])
# Number of examples: 16969
#
# === Iteration 1/10 ===
#
# --- Fold 1/5 ---
# Epoch 100 | Loss: 0.5090
# Epoch 200 | Loss: 0.4591
# Epoch 300 | Loss: 0.4869
# Epoch 400 | Loss: 0.4183
# Metrics | Precision: 0.8817 | Recall: 0.8723 | F1: 0.8770 | Kappa: 0.7553
#
# --- Fold 2/5 ---
# Epoch 100 | Loss: 0.4086
# Epoch 200 | Loss: 0.3749
# Epoch 300 | Loss: 0.3799
# Epoch 400 | Loss: 0.3899
# Metrics | Precision: 0.7313 | Recall: 0.8448 | F1: 0.7840 | Kappa: 0.5345
#
# --- Fold 3/5 ---
# Epoch 100 | Loss: 0.5226
# Epoch 200 | Loss: 0.3823
# Epoch 300 | Loss: 0.3776
# Epoch 400 | Loss: 0.3743
# Metrics | Precision: 0.8600 | Recall: 0.5375 | F1: 0.6615 | Kappa: 0.4500
#
# --- Fold 4/5 ---
# Epoch 100 | Loss: 0.4273
# Epoch 200 | Loss: 0.4196
# Epoch 300 | Loss: 0.4025
# Epoch 400 | Loss: 0.3787
# Metrics | Precision: 0.8529 | Recall: 0.7785 | F1: 0.8140 | Kappa: 0.6443
#
# --- Fold 5/5 ---
# Epoch 100 | Loss: 0.5350
# Epoch 200 | Loss: 0.4594
# Epoch 300 | Loss: 0.4106
# Epoch 400 | Loss: 0.4061
# Metrics | Precision: 0.8699 | Recall: 0.8843 | F1: 0.8770 | Kappa: 0.7521
#
# === Iteration 2/10 ===
#
# --- Fold 1/5 ---
# Epoch 100 | Loss: 0.4779
# Epoch 200 | Loss: 0.5450
# Epoch 300 | Loss: 0.4785
# Epoch 400 | Loss: 0.4416
# Metrics | Precision: 0.8617 | Recall: 0.8617 | F1: 0.8617 | Kappa: 0.7234
#
# --- Fold 2/5 ---
# Epoch 100 | Loss: 0.4602
# Epoch 200 | Loss: 0.3481
# Epoch 300 | Loss: 0.3308
# Epoch 400 | Loss: 0.3500
# Metrics | Precision: 0.6736 | Recall: 0.8362 | F1: 0.7462 | Kappa: 0.4310
#
# --- Fold 3/5 ---
# Epoch 100 | Loss: 0.4172
# Epoch 200 | Loss: 0.3995
# Epoch 300 | Loss: 0.4056
# Epoch 400 | Loss: 0.3896
# Metrics | Precision: 0.7733 | Recall: 0.7250 | F1: 0.7484 | Kappa: 0.5125
#
# --- Fold 4/5 ---
# Epoch 100 | Loss: 0.4343
# Epoch 200 | Loss: 0.4636
# Epoch 300 | Loss: 0.4196
# Epoch 400 | Loss: 0.3850
# Metrics | Precision: 0.8626 | Recall: 0.7584 | F1: 0.8071 | Kappa: 0.6376
#
# --- Fold 5/5 ---
# Epoch 100 | Loss: 0.4666
# Epoch 200 | Loss: 0.4840
# Epoch 300 | Loss: 0.4187
# Epoch 400 | Loss: 0.4216
# Metrics | Precision: 0.8321 | Recall: 0.9008 | F1: 0.8651 | Kappa: 0.7190
#
# === Iteration 3/10 ===
#
# --- Fold 1/5 ---
# Epoch 100 | Loss: 0.4980
# Epoch 200 | Loss: 0.4400
# Epoch 300 | Loss: 0.4724
# Epoch 400 | Loss: 0.4719
# Metrics | Precision: 0.8916 | Recall: 0.7872 | F1: 0.8362 | Kappa: 0.6915
#
# --- Fold 2/5 ---
# Epoch 100 | Loss: 0.4863
# Epoch 200 | Loss: 0.3780
# Epoch 300 | Loss: 0.3776
# Epoch 400 | Loss: 0.3677
# Metrics | Precision: 0.8864 | Recall: 0.3362 | F1: 0.4875 | Kappa: 0.2931
#
# --- Fold 3/5 ---
# Epoch 100 | Loss: 0.4159
# Epoch 200 | Loss: 0.3852
# Epoch 300 | Loss: 0.3722
# Epoch 400 | Loss: 0.3654
# Metrics | Precision: 0.7368 | Recall: 0.7000 | F1: 0.7179 | Kappa: 0.4500
#
# --- Fold 4/5 ---
# Epoch 100 | Loss: 0.4993
# Epoch 200 | Loss: 0.4327
# Epoch 300 | Loss: 0.4055
# Epoch 400 | Loss: 0.4085
# Metrics | Precision: 0.8403 | Recall: 0.8121 | F1: 0.8259 | Kappa: 0.6577
#
# --- Fold 5/5 ---
# Epoch 100 | Loss: 0.4594
# Epoch 200 | Loss: 0.4542
# Epoch 300 | Loss: 0.4392
# Epoch 400 | Loss: 0.4366
# Metrics | Precision: 0.8286 | Recall: 0.9587 | F1: 0.8889 | Kappa: 0.7603
#
# === Iteration 4/10 ===
#
# --- Fold 1/5 ---
# Epoch 100 | Loss: 0.5130
# Epoch 200 | Loss: 0.4736
# Epoch 300 | Loss: 0.4476
# Epoch 400 | Loss: 0.4316
# Metrics | Precision: 0.8989 | Recall: 0.8511 | F1: 0.8743 | Kappa: 0.7553
#
# --- Fold 2/5 ---
# Epoch 100 | Loss: 0.3708
# Epoch 200 | Loss: 0.3478
# Epoch 300 | Loss: 0.3690
# Epoch 400 | Loss: 0.3779
# Metrics | Precision: 0.7885 | Recall: 0.7069 | F1: 0.7455 | Kappa: 0.5172
#
# --- Fold 3/5 ---
# Epoch 100 | Loss: 0.4128
# Epoch 200 | Loss: 0.3850
# Epoch 300 | Loss: 0.4117
# Epoch 400 | Loss: 0.3676
# Metrics | Precision: 0.7654 | Recall: 0.7750 | F1: 0.7702 | Kappa: 0.5375
#
# --- Fold 4/5 ---
# Epoch 100 | Loss: 0.4010
# Epoch 200 | Loss: 0.3818
# Epoch 300 | Loss: 0.4755
# Epoch 400 | Loss: 0.3827
# Metrics | Precision: 0.7829 | Recall: 0.7987 | F1: 0.7907 | Kappa: 0.5772
#
# --- Fold 5/5 ---
# Epoch 100 | Loss: 0.4798
# Epoch 200 | Loss: 0.4449
# Epoch 300 | Loss: 0.4514
# Epoch 400 | Loss: 0.4178
# Metrics | Precision: 0.8296 | Recall: 0.9256 | F1: 0.8750 | Kappa: 0.7355
#
# === Iteration 5/10 ===
#
# --- Fold 1/5 ---
# Epoch 100 | Loss: 0.4462
# Epoch 200 | Loss: 0.4393
# Epoch 300 | Loss: 0.4301
# Epoch 400 | Loss: 0.5336
# Metrics | Precision: 0.9011 | Recall: 0.8723 | F1: 0.8865 | Kappa: 0.7766
#
# --- Fold 2/5 ---
# Epoch 100 | Loss: 0.3979
# Epoch 200 | Loss: 0.4861
# Epoch 300 | Loss: 0.4347
# Epoch 400 | Loss: 0.3834
# Metrics | Precision: 0.8090 | Recall: 0.6207 | F1: 0.7024 | Kappa: 0.4741
#
# --- Fold 3/5 ---
# Epoch 100 | Loss: 0.4025
# Epoch 200 | Loss: 0.3710
# Epoch 300 | Loss: 0.3734
# Epoch 400 | Loss: 0.3658
# Metrics | Precision: 0.7033 | Recall: 0.8000 | F1: 0.7485 | Kappa: 0.4625
#
# --- Fold 4/5 ---
# Epoch 100 | Loss: 0.4215
# Epoch 200 | Loss: 0.4259
# Epoch 300 | Loss: 0.3985
# Epoch 400 | Loss: 0.3616
# Metrics | Precision: 0.8345 | Recall: 0.7785 | F1: 0.8056 | Kappa: 0.6242
#
# --- Fold 5/5 ---
# Epoch 100 | Loss: 0.4965
# Epoch 200 | Loss: 0.5268
# Epoch 300 | Loss: 0.4590
# Epoch 400 | Loss: 0.4753
# Metrics | Precision: 0.7763 | Recall: 0.9752 | F1: 0.8645 | Kappa: 0.6942
#
# === Iteration 6/10 ===
#
# --- Fold 1/5 ---
# Epoch 100 | Loss: 0.4740
# Epoch 200 | Loss: 0.4885
# Epoch 300 | Loss: 0.4453
# Epoch 400 | Loss: 0.4580
# Metrics | Precision: 0.9157 | Recall: 0.8085 | F1: 0.8588 | Kappa: 0.7340
#
# --- Fold 2/5 ---
# Epoch 100 | Loss: 0.3882
# Epoch 200 | Loss: 0.3973
# Epoch 300 | Loss: 0.3623
# Epoch 400 | Loss: 0.3545
# Metrics | Precision: 0.7935 | Recall: 0.6293 | F1: 0.7019 | Kappa: 0.4655
#
# --- Fold 3/5 ---
# Epoch 100 | Loss: 0.3905
# Epoch 200 | Loss: 0.3841
# Epoch 300 | Loss: 0.3762
# Epoch 400 | Loss: 0.3936
# Metrics | Precision: 0.8333 | Recall: 0.3125 | F1: 0.4545 | Kappa: 0.2500
#
# --- Fold 4/5 ---
# Epoch 100 | Loss: 0.4089
# Epoch 200 | Loss: 0.4143
# Epoch 300 | Loss: 0.3932
# Epoch 400 | Loss: 0.3557
# Metrics | Precision: 0.7514 | Recall: 0.8725 | F1: 0.8075 | Kappa: 0.5839
#
# --- Fold 5/5 ---
# Epoch 100 | Loss: 0.4330
# Epoch 200 | Loss: 0.4423
# Epoch 300 | Loss: 0.4794
# Epoch 400 | Loss: 0.4184
# Metrics | Precision: 0.7867 | Recall: 0.9752 | F1: 0.8708 | Kappa: 0.7107
#
# === Iteration 7/10 ===
#
# --- Fold 1/5 ---
# Epoch 100 | Loss: 0.4876
# Epoch 200 | Loss: 0.4298
# Epoch 300 | Loss: 0.4123
# Epoch 400 | Loss: 0.4238
# Metrics | Precision: 0.9080 | Recall: 0.8404 | F1: 0.8729 | Kappa: 0.7553
#
# --- Fold 2/5 ---
# Epoch 100 | Loss: 0.4202
# Epoch 200 | Loss: 0.4269
# Epoch 300 | Loss: 0.3669
# Epoch 400 | Loss: 0.3608
# Metrics | Precision: 0.7540 | Recall: 0.8190 | F1: 0.7851 | Kappa: 0.5517
#
# --- Fold 3/5 ---
# Epoch 100 | Loss: 0.3920
# Epoch 200 | Loss: 0.4926
# Epoch 300 | Loss: 0.3890
# Epoch 400 | Loss: 0.3821
# Metrics | Precision: 0.8462 | Recall: 0.4125 | F1: 0.5546 | Kappa: 0.3375
#
# --- Fold 4/5 ---
# Epoch 100 | Loss: 0.4038
# Epoch 200 | Loss: 0.3733
# Epoch 300 | Loss: 0.3691
# Epoch 400 | Loss: 0.3670
# Metrics | Precision: 0.8284 | Recall: 0.7450 | F1: 0.7845 | Kappa: 0.5906
#
# --- Fold 5/5 ---
# Epoch 100 | Loss: 0.4418
# Epoch 200 | Loss: 0.4600
# Epoch 300 | Loss: 0.4271
# Epoch 400 | Loss: 0.4705
# Metrics | Precision: 0.8699 | Recall: 0.8843 | F1: 0.8770 | Kappa: 0.7521
#
# === Iteration 8/10 ===
#
# --- Fold 1/5 ---
# Epoch 100 | Loss: 0.7123
# Epoch 200 | Loss: 0.4474
# Epoch 300 | Loss: 0.4543
# Epoch 400 | Loss: 0.4610
# Metrics | Precision: 0.9405 | Recall: 0.8404 | F1: 0.8876 | Kappa: 0.7872
#
# --- Fold 2/5 ---
# Epoch 100 | Loss: 0.4075
# Epoch 200 | Loss: 0.3991
# Epoch 300 | Loss: 0.3684
# Epoch 400 | Loss: 0.3670
# Metrics | Precision: 0.6347 | Recall: 0.9138 | F1: 0.7491 | Kappa: 0.3879
#
# --- Fold 3/5 ---
# Epoch 100 | Loss: 0.5122
# Epoch 200 | Loss: 0.4182
# Epoch 300 | Loss: 0.3771
# Epoch 400 | Loss: 0.4117
# Metrics | Precision: 0.6737 | Recall: 0.8000 | F1: 0.7314 | Kappa: 0.4125
#
# --- Fold 4/5 ---
# Epoch 100 | Loss: 0.4274
# Epoch 200 | Loss: 0.4057
# Epoch 300 | Loss: 0.4321
# Epoch 400 | Loss: 0.4002
# Metrics | Precision: 0.8571 | Recall: 0.7248 | F1: 0.7855 | Kappa: 0.6040
#
# --- Fold 5/5 ---
# Epoch 100 | Loss: 0.4461
# Epoch 200 | Loss: 0.5264
# Epoch 300 | Loss: 0.4268
# Epoch 400 | Loss: 0.4204
# Metrics | Precision: 0.9076 | Recall: 0.8926 | F1: 0.9000 | Kappa: 0.8017
#
# === Iteration 9/10 ===
#
# --- Fold 1/5 ---
# Epoch 100 | Loss: 0.4788
# Epoch 200 | Loss: 0.4677
# Epoch 300 | Loss: 0.4287
# Epoch 400 | Loss: 0.4509
# Metrics | Precision: 0.8817 | Recall: 0.8723 | F1: 0.8770 | Kappa: 0.7553
#
# --- Fold 2/5 ---
# Epoch 100 | Loss: 0.4053
# Epoch 200 | Loss: 0.3717
# Epoch 300 | Loss: 0.4176
# Epoch 400 | Loss: 0.3725
# Metrics | Precision: 0.9189 | Recall: 0.2931 | F1: 0.4444 | Kappa: 0.2672
#
# --- Fold 3/5 ---
# Epoch 100 | Loss: 0.4029
# Epoch 200 | Loss: 0.3791
# Epoch 300 | Loss: 0.3817
# Epoch 400 | Loss: 0.3655
# Metrics | Precision: 0.7714 | Recall: 0.6750 | F1: 0.7200 | Kappa: 0.4750
#
# --- Fold 4/5 ---
# Epoch 100 | Loss: 0.4282
# Epoch 200 | Loss: 0.4642
# Epoch 300 | Loss: 0.4814
# Epoch 400 | Loss: 0.3970
# Metrics | Precision: 0.8981 | Recall: 0.6510 | F1: 0.7549 | Kappa: 0.5772
#
# --- Fold 5/5 ---
# Epoch 100 | Loss: 0.5073
# Epoch 200 | Loss: 0.4557
# Epoch 300 | Loss: 0.4675
# Epoch 400 | Loss: 0.4694
# Metrics | Precision: 0.8537 | Recall: 0.8678 | F1: 0.8607 | Kappa: 0.7190
#
# === Iteration 10/10 ===
#
# --- Fold 1/5 ---
# Epoch 100 | Loss: 0.5657
# Epoch 200 | Loss: 0.5462
# Epoch 300 | Loss: 0.4318
# Epoch 400 | Loss: 0.4510
# Metrics | Precision: 0.9268 | Recall: 0.8085 | F1: 0.8636 | Kappa: 0.7447
#
# --- Fold 2/5 ---
# Epoch 100 | Loss: 0.3672
# Epoch 200 | Loss: 0.3894
# Epoch 300 | Loss: 0.3736
# Epoch 400 | Loss: 0.3367
# Metrics | Precision: 0.7568 | Recall: 0.4828 | F1: 0.5895 | Kappa: 0.3276
#
# --- Fold 3/5 ---
# Epoch 100 | Loss: 0.4021
# Epoch 200 | Loss: 0.4046
# Epoch 300 | Loss: 0.3875
# Epoch 400 | Loss: 0.3969
# Metrics | Precision: 0.7284 | Recall: 0.7375 | F1: 0.7329 | Kappa: 0.4625
#
# --- Fold 4/5 ---
# Epoch 100 | Loss: 0.4264
# Epoch 200 | Loss: 0.4216
# Epoch 300 | Loss: 0.3897
# Epoch 400 | Loss: 0.4037
# Metrics | Precision: 0.7867 | Recall: 0.7919 | F1: 0.7893 | Kappa: 0.5772
#
# --- Fold 5/5 ---
# Epoch 100 | Loss: 0.4896
# Epoch 200 | Loss: 0.4947
# Epoch 300 | Loss: 0.4797
# Epoch 400 | Loss: 0.4500
# Metrics | Precision: 0.9174 | Recall: 0.9174 | F1: 0.9174 | Kappa: 0.8347
#
# --- Per-zone results over 10 iterations ---
#
# Zone 1
# Precision: 0.90 ± 0.02
# Recall:    0.84 ± 0.03
# F1:        0.87 ± 0.01
# Kappa:     0.75 ± 0.03
#
# Zone 2
# Precision: 0.77 ± 0.08
# Recall:    0.65 ± 0.21
# F1:        0.67 ± 0.12
# Kappa:     0.43 ± 0.10
#
# Zone 3
# Precision: 0.77 ± 0.06
# Recall:    0.65 ± 0.16
# F1:        0.68 ± 0.10
# Kappa:     0.43 ± 0.08
#
# Zone 4
# Precision: 0.83 ± 0.04
# Recall:    0.77 ± 0.06
# F1:        0.80 ± 0.02
# Kappa:     0.61 ± 0.03
#
# Zone 5
# Precision: 0.85 ± 0.04
# Recall:    0.92 ± 0.04
# F1:        0.88 ± 0.02
# Kappa:     0.75 ± 0.04
#
# --- Global averages across all zones ---
# Precision: 0.82 ± 0.05
# Recall:    0.77 ± 0.11
# F1:        0.78 ± 0.09
# Kappa:     0.59 ± 0.14
